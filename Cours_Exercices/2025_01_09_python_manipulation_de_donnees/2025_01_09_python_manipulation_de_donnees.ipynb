# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Importer Pandas.

# %%
import pandas as pd

# %% [markdown]
# Charger le fichier CSV.

# %%
df = pd.read_csv('offre-touristique-hebergements-locatifs-rpdl.csv', sep=';', on_bad_lines='skip')

# %%
df.head()
# Out:
#                          nomoffre     type typehabitation adresse1  \
# 0                 Chalet meublé 1  Meublés         Chalet      NaN
# 1                   Gîte du Chêne  Meublés    Appartement      NaN
# 2  Gîte de La Janais - Hortensias  Meublés         Maison      NaN
# 3       Gîte Le Jardin des Aulnes  Meublés            NaN      NaN
# 4                   GITE LA FORGE  Meublés         Maison      NaN
#
#   adresse1suite adresse2 adresse3  codepostal              commune  cedex  \
# 0           NaN      NaN      NaN     72700.0                 SPAY    NaN
# 1           NaN      NaN      NaN     72140.0  SAINT-REMY-DE-SILLE    NaN
# 2           NaN      NaN      NaN     44540.0               LE PIN    NaN
# 3           NaN      NaN      NaN     72320.0             VALENNES    NaN
# 4           NaN      NaN      NaN     53420.0            CHAILLAND    NaN
#
#    ...  ouverturealannee  ouverturegranule  \
# 0  ...               NaN               NaN
# ...

# %%
df.shape
# Out:
# (3904, 51)

# %% [markdown]
# Nettoyer les données.

# %%
df.isnull().sum()
# Out:
# nomoffre                           0
# type                               6
# typehabitation                   758
# adresse1                        3604
# adresse1suite                   3767
# adresse2                         576
# adresse3                        2526
# codepostal                         8
# commune                            0
# cedex                           3896
# codeinseecommune                   0
# latitude                           0
# longitude                          0
# acces                           2431
# commmob                         2048
# commtel                         1697
# commfax                         3841
# commmail                        3904
# commweb                         1731
# videosurl                       3745
# plateformeurl                   2828
# spvideosembed                   3834
# tripadwidget                    3884
# animauxacceptes                  969
# animauxinfo                     3359
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.fillna(0, inplace=True)
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# nomoffre                        0
# type                            0
# typehabitation                  0
# adresse1                        0
# adresse1suite                   0
# adresse2                        0
# adresse3                        0
# codepostal                      0
# commune                         0
# cedex                           0
# codeinseecommune                0
# latitude                        0
# longitude                       0
# acces                           0
# commmob                         0
# commtel                         0
# commfax                         0
# commmail                        0
# commweb                         0
# videosurl                       0
# plateformeurl                   0
# spvideosembed                   0
# tripadwidget                    0
# animauxacceptes                 0
# animauxinfo                     0
# labeltourismehandicap           0
# spaccessibilite                 0
# ...

# %%
df.head()
# Out:
#                          nomoffre     type typehabitation adresse1  \
# 0                 Chalet meublé 1  Meublés         Chalet        0
# 1                   Gîte du Chêne  Meublés    Appartement        0
# 2  Gîte de La Janais - Hortensias  Meublés         Maison        0
# 3       Gîte Le Jardin des Aulnes  Meublés              0        0
# 4                   GITE LA FORGE  Meublés         Maison        0
#
#   adresse1suite adresse2 adresse3  codepostal              commune  cedex  \
# 0             0        0        0     72700.0                 SPAY    0.0
# 1             0        0        0     72140.0  SAINT-REMY-DE-SILLE    0.0
# 2             0        0        0     44540.0               LE PIN    0.0
# 3             0        0        0     72320.0             VALENNES    0.0
# 4             0        0        0     53420.0            CHAILLAND    0.0
#
#    ...  ouverturealannee  ouverturegranule  \
# 0  ...                 0                 0
# ...

# %% [markdown]
# Transformer les données.

# %%
df.columns
# Out:
# Index(['nomoffre', 'type', 'typehabitation', 'adresse1', 'adresse1suite',
#        'adresse2', 'adresse3', 'codepostal', 'commune', 'cedex',
#        'codeinseecommune', 'latitude', 'longitude', 'acces', 'commmob',
#        'commtel', 'commfax', 'commmail', 'commweb', 'videosurl',
#        'plateformeurl', 'spvideosembed', 'tripadwidget', 'animauxacceptes',
#        'animauxinfo', 'labeltourismehandicap', 'spaccessibilite',
#        'spaccueilveloitineraire', 'equipements', 'confortimmobilier',
#        'confortmobilier', 'labels', 'labelsclassement', 'categorie',
#        'capacitenbchambres', 'capacitenbchambresmobreduite',
#        'capacitenbhebergements', 'capacitenbpersonnes', 'capacitesurface',
#        'services', 'languesparleesaccueil', 'ouverturealannee',
#        'ouverturegranule', 'resadirecte', 'resaenligneouinon', 'resaenligne',
#        'resaagence', 'tarifs', 'modepaiement', 'localisation', 'departement'],
#       dtype='object')

# %%
df_filtre = df[df['resaenligneouinon'] == 'oui']
print(df_filtre)
# Out:
#                                                nomoffre                  type  \
# 2                        Gîte de La Janais - Hortensias               Meublés
# 5                       Gîte de La Janais - Coquelicots               Meublés
# 6                                     LA CABANE SECRÈTE  Hébergement insolite
# 9                   Chambres d'hôtes et Spa la Forcerie      Chambres d'hôtes
# 16              CHAMBRES D'HÔTE - P'TIT LOFT À LA FERME      Chambres d'hôtes
# ...                                                 ...                   ...
# 3881  Village Vacances et Pêche de Villiers-Charlemagne       Village locatif
# 3883    TENTES CANADA - CAMPING ONLYCAMP LE PONT ROMAIN   Locatif sur camping
# 3885                                 GITE LA JOUANNERIE               Meublés
# 3894               TIPI AU CAMPING DU GUE SAINT-LEONARD  Hébergement insolite
# 3903                   Gîte Gîte De Cinq Ans : Le Grand               Meublés
#
# ...

# %% [markdown]
# Exporter le résultat dans un nouveau fichier CSV.

# %%
df.to_csv("fichier_propre_tourisme_au_pays_de_la_loire.csv", index=False)

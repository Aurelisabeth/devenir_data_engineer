# %% [markdown]
# ## S1J5 (Projet) : Créer un script Python pour nettoyer un fichier CSV contenant des données erronées.
# ### **Objectif :**
#
# - Comprendre comment analyser, nettoyer et transformer des données brutes.
# - Appliquer les concepts appris dans la semaine sur un projet pratique.
# - Produire un fichier propre prêt à être utilisé dans des pipelines de données.
#
# ---
#
# ### **Contexte :**
#
# Vous avez reçu un fichier CSV contenant des données clients pour une entreprise. Cependant, ce fichier est incomplet et contient des erreurs courantes (valeurs manquantes, doublons, types incorrects). Votre mission est de nettoyer ce fichier et d’en produire une version exploitable.

# %% [markdown]
# ### **Étapes du projet :**
#
# ### **1. Charger le fichier CSV.**
#
# Commencez par charger le fichier dans un DataFrame Pandas. Analysez rapidement son contenu.

# %%
import pandas as pd

# Charger le fichier CSV
df = pd.read_csv("44.csv")

# Aperçu des données
print(df.head())
print(df.info())
print(df.describe())
# Out:
# C:\Users\Aurélie\AppData\Local\Temp\ipykernel_21064\1438981477.py:4: DtypeWarning: Columns (17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("44.csv")
#    id_mutation date_mutation  numero_disposition nature_mutation  \
# 0  2023-235485    2023-01-03                   1           Vente
# 1  2023-235486    2023-01-03                   1           Vente
# 2  2023-235487    2023-01-03                   1           Vente
# 3  2023-235487    2023-01-03                   1           Vente
# 4  2023-235488    2023-01-03                   1           Vente
#
#    valeur_fonciere  adresse_numero adresse_suffixe        adresse_nom_voie  \
# 0           3500.0             NaN             NaN          LA GRANDE HAIE
# 1             47.0             8.0             NaN  RUE DE LA MOUCHONNERIE
# 2         275000.0            75.0             NaN         RUE DES PLANTES
# 3         275000.0            75.0             NaN         RUE DES PLANTES
# 4         185000.0             4.0             NaN         RUE DE JEMMAPES
#
#   adresse_code_voie  code_postal  ...   type_local surface_reelle_bati  \
# 0              B793      44119.0  ...          NaN                 NaN
# 1              2200      44340.0  ...          NaN                 NaN
# 2              1080      44230.0  ...       Maison                71.0
# 3              1080      44230.0  ...   Dépendance                 NaN
# 4              4524      44000.0  ...  Appartement                48.0
#
#    nombre_pieces_principales  code_nature_culture  nature_culture  \
# 0                        NaN                    T          terres
# 1                        NaN                    S            sols
# 2                        4.0                    S            sols
# 3                        0.0                    S            sols
# 4                        2.0                  NaN             NaN
#
#   code_nature_culture_speciale  nature_culture_speciale surface_terrain  \
# 0                          NaN                      NaN           629.0
# 1                          NaN                      NaN            47.0
# 2                          NaN                      NaN           448.0
# 3                          NaN                      NaN           448.0
# 4                          NaN                      NaN             NaN
#
#   longitude   latitude
# 0 -1.639538  47.372786
# 1 -1.653142  47.178028
# 2 -1.480784  47.194929
# 3 -1.480784  47.194929
# 4 -1.545653  47.213273
#
# [5 rows x 40 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40369 entries, 0 to 40368
# Data columns (total 40 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id_mutation                   40369 non-null  object
#  1   date_mutation                 40369 non-null  object
#  2   numero_disposition            40369 non-null  int64
#  3   nature_mutation               40369 non-null  object
#  4   valeur_fonciere               39956 non-null  float64
#  5   adresse_numero                27341 non-null  float64
#  6   adresse_suffixe               1506 non-null   object
#  7   adresse_nom_voie              40264 non-null  object
#  8   adresse_code_voie             40272 non-null  object
#  9   code_postal                   40272 non-null  float64
#  10  code_commune                  40369 non-null  int64
#  11  nom_commune                   40369 non-null  object
#  12  code_departement              40369 non-null  int64
#  13  ancien_code_commune           0 non-null      float64
#  14  ancien_nom_commune            0 non-null      float64
#  15  id_parcelle                   40369 non-null  object
#  16  ancien_id_parcelle            0 non-null      float64
#  17  numero_volume                 80 non-null     object
#  18  lot1_numero                   13150 non-null  object
#  19  lot1_surface_carrez           3210 non-null   float64
#  20  lot2_numero                   3894 non-null   float64
#  21  lot2_surface_carrez           1153 non-null   float64
#  22  lot3_numero                   692 non-null    float64
#  23  lot3_surface_carrez           77 non-null     float64
#  24  lot4_numero                   240 non-null    float64
#  25  lot4_surface_carrez           27 non-null     float64
#  26  lot5_numero                   116 non-null    float64
#  27  lot5_surface_carrez           5 non-null      float64
#  28  nombre_lots                   40369 non-null  int64
#  29  code_type_local               23639 non-null  float64
#  30  type_local                    23639 non-null  object
#  31  surface_reelle_bati           12860 non-null  float64
#  32  nombre_pieces_principales     23626 non-null  float64
#  33  code_nature_culture           26937 non-null  object
#  34  nature_culture                26937 non-null  object
#  35  code_nature_culture_speciale  408 non-null    object
#  36  nature_culture_speciale       408 non-null    object
#  37  surface_terrain               26936 non-null  float64
#  38  longitude                     39822 non-null  float64
#  39  latitude                      39822 non-null  float64
# dtypes: float64(21), int64(4), object(15)
# memory usage: 12.3+ MB
# None
#        numero_disposition  valeur_fonciere  adresse_numero   code_postal  \
# count        40369.000000     3.995600e+04    27341.000000  40272.000000
# mean             1.038891     4.259190e+05      435.723712  44386.152885
# std              0.227372     1.689604e+06     1609.808403    238.187139
# min              1.000000     1.500000e-01        1.000000  44000.000000
# 25%              1.000000     8.845000e+04        6.000000  44200.000000
# 50%              1.000000     1.900000e+05       17.000000  44360.000000
# 75%              1.000000     3.192008e+05       47.000000  44580.000000
# max             10.000000     4.575720e+07     9999.000000  44980.000000
#
#        code_commune  code_departement  ancien_code_commune  \
# count  40369.000000           40369.0                  0.0
# mean   44113.973965              44.0                  NaN
# std       57.807480               0.0                  NaN
# min    44001.000000              44.0                  NaN
# 25%    44069.000000              44.0                  NaN
# 50%    44109.000000              44.0                  NaN
# 75%    44162.000000              44.0                  NaN
# max    44224.000000              44.0                  NaN
#
#        ancien_nom_commune  ancien_id_parcelle  lot1_surface_carrez  ...  \
# count                 0.0                 0.0          3210.000000  ...
# mean                  NaN                 NaN            58.910371  ...
# std                   NaN                 NaN            50.566488  ...
# min                   NaN                 NaN             2.350000  ...
# 25%                   NaN                 NaN            38.537500  ...
# 50%                   NaN                 NaN            55.660000  ...
# 75%                   NaN                 NaN            70.792500  ...
# max                   NaN                 NaN          1361.510000  ...
#
#        lot4_surface_carrez  lot5_numero  lot5_surface_carrez   nombre_lots  \
# count            27.000000   116.000000             5.000000  40369.000000
# mean             65.430741   123.663793            58.038000      0.474572
# std              43.018711   450.083837            24.620998      1.799545
# min              14.650000     2.000000            14.090000      0.000000
# 25%              32.040000     8.000000            66.220000      0.000000
# 50%              34.560000    29.000000            69.960000      0.000000
# 75%              95.960000    68.000000            69.960000      1.000000
# max             189.200000  3501.000000            69.960000    150.000000
#
#        code_type_local  surface_reelle_bati  nombre_pieces_principales  \
# count     23639.000000         12860.000000               23626.000000
# mean          2.239181           111.365319                   1.763523
# std           0.931436           341.017665                   2.089589
# min           1.000000             2.000000                   0.000000
# 25%           1.000000            51.000000                   0.000000
# 50%           2.000000            77.000000                   1.000000
# 75%           3.000000           106.000000                   3.000000
# max           4.000000         11696.000000                  18.000000
#
#        surface_terrain     longitude      latitude
# count     26936.000000  39822.000000  39822.000000
# mean       2325.117612     -1.720146     47.277135
# std        7382.177877      0.339670      0.158763
# min           1.000000     -2.555405     46.862847
# 25%         202.000000     -1.973191     47.192832
# 50%         500.000000     -1.588555     47.243008
# 75%        1159.000000     -1.515225     47.345185
# max      239167.000000     -0.954019     47.831041
#
# [8 rows x 25 columns]

# %%
# Affichage de la liste de toutes les colonnes.
df.columns
# Out:
# Index(['id_mutation', 'date_mutation', 'numero_disposition', 'nature_mutation',
#        'valeur_fonciere', 'adresse_numero', 'adresse_suffixe',
#        'adresse_nom_voie', 'adresse_code_voie', 'code_postal', 'code_commune',
#        'nom_commune', 'code_departement', 'ancien_code_commune',
#        'ancien_nom_commune', 'id_parcelle', 'ancien_id_parcelle',
#        'numero_volume', 'lot1_numero', 'lot1_surface_carrez', 'lot2_numero',
#        'lot2_surface_carrez', 'lot3_numero', 'lot3_surface_carrez',
#        'lot4_numero', 'lot4_surface_carrez', 'lot5_numero',
#        'lot5_surface_carrez', 'nombre_lots', 'code_type_local', 'type_local',
#        'surface_reelle_bati', 'nombre_pieces_principales',
#        'code_nature_culture', 'nature_culture', 'code_nature_culture_speciale',
#        'nature_culture_speciale', 'surface_terrain', 'longitude', 'latitude'],
#       dtype='object')

# %% [markdown]
# ### **2. Identifier les problèmes.**
#
# Voici des exemples de problèmes courants à chercher dans vos données :
#
# - **Valeurs manquantes** : Certaines colonnes peuvent contenir des NaN (Not a Number).
# - **Doublons** : Plusieurs lignes identiques ou proches.
# - **Erreurs de type** : Par exemple, des dates enregistrées comme texte ou des nombres mal formatés.
# - **Valeurs aberrantes** : Des âges négatifs, des revenus excessivement élevés ou nuls, etc.

# %%
# Détecter et supprimer les doublons.
df.drop_duplicates(inplace=True)

# Traiter les valeurs manquantes : Vérification.
df.isnull().sum()
# Out:
# id_mutation                         0
# date_mutation                       0
# numero_disposition                  0
# nature_mutation                     0
# valeur_fonciere                   405
# adresse_numero                  12930
# adresse_suffixe                 36840
# adresse_nom_voie                  105
# adresse_code_voie                  97
# code_postal                        97
# code_commune                        0
# nom_commune                         0
# code_departement                    0
# ancien_code_commune             38270
# ancien_nom_commune              38270
# id_parcelle                         0
# ancien_id_parcelle              38270
# numero_volume                   38190
# lot1_numero                     25605
# lot1_surface_carrez             35188
# lot2_numero                     34745
# lot2_surface_carrez             37219
# lot3_numero                     37716
# lot3_surface_carrez             38205
# lot4_numero                     38080
# lot4_surface_carrez             38251
# lot5_numero                     38173
# lot5_surface_carrez             38266
# nombre_lots                         0
# code_type_local                 16617
# type_local                      16617
# surface_reelle_bati             25536
# nombre_pieces_principales       16630
# code_nature_culture             12916
# nature_culture                  12916
# code_nature_culture_speciale    37875
# nature_culture_speciale         37875
# surface_terrain                 12917
# longitude                         509
# latitude                          509
# dtype: int64

# %%
# Vérifier le type de données par colonnes.
print(df.dtypes)
# Out:
# id_mutation                      object
# date_mutation                    object
# numero_disposition                int64
# nature_mutation                  object
# valeur_fonciere                 float64
# adresse_numero                  float64
# adresse_suffixe                  object
# adresse_nom_voie                 object
# adresse_code_voie                object
# code_postal                     float64
# code_commune                      int64
# nom_commune                      object
# code_departement                  int64
# ancien_code_commune             float64
# ancien_nom_commune              float64
# id_parcelle                      object
# ancien_id_parcelle              float64
# numero_volume                    object
# lot1_numero                      object
# lot1_surface_carrez             float64
# lot2_numero                     float64
# lot2_surface_carrez             float64
# lot3_numero                     float64
# lot3_surface_carrez             float64
# lot4_numero                     float64
# lot4_surface_carrez             float64
# lot5_numero                     float64
# lot5_surface_carrez             float64
# nombre_lots                       int64
# code_type_local                 float64
# type_local                       object
# surface_reelle_bati             float64
# nombre_pieces_principales       float64
# code_nature_culture              object
# nature_culture                   object
# code_nature_culture_speciale     object
# nature_culture_speciale          object
# surface_terrain                 float64
# longitude                       float64
# latitude                        float64
# dtype: object

# %%
# Application des remplacements en fonction du type de chaque colonne.
for col in df.columns:
    # Si la colonne est de type "object" (chaîne de caractères).
    if df[col].dtype == "object":  
        df[col] = df[col].fillna("Inconnu")
    # Si la colonne est de type "float64".
    elif df[col].dtype == "float64":  
        df[col] = df[col].fillna(0.00)
    # Si la colonne est de type "int64".
    elif df[col].dtype == "int64":
        df[col] = df[col].fillna(0)
        
# Vérification.
df.isnull().sum()
# Out:
# id_mutation                     0
# date_mutation                   0
# numero_disposition              0
# nature_mutation                 0
# valeur_fonciere                 0
# adresse_numero                  0
# adresse_suffixe                 0
# adresse_nom_voie                0
# adresse_code_voie               0
# code_postal                     0
# code_commune                    0
# nom_commune                     0
# code_departement                0
# ancien_code_commune             0
# ancien_nom_commune              0
# id_parcelle                     0
# ancien_id_parcelle              0
# numero_volume                   0
# lot1_numero                     0
# lot1_surface_carrez             0
# lot2_numero                     0
# lot2_surface_carrez             0
# lot3_numero                     0
# lot3_surface_carrez             0
# lot4_numero                     0
# lot4_surface_carrez             0
# lot5_numero                     0
# lot5_surface_carrez             0
# nombre_lots                     0
# code_type_local                 0
# type_local                      0
# surface_reelle_bati             0
# nombre_pieces_principales       0
# code_nature_culture             0
# nature_culture                  0
# code_nature_culture_speciale    0
# nature_culture_speciale         0
# surface_terrain                 0
# longitude                       0
# latitude                        0
# dtype: int64

# %% [markdown]
# ### **3. Sauvegarder le fichier nettoyé.**
#
# Exportez le fichier nettoyé pour qu’il puisse être utilisé dans un autre pipeline ou une analyse.

# %%
df.to_csv("44_clean.csv", index=False)
